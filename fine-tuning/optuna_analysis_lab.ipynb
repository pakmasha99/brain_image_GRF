# %%
import optuna
import os 

import optuna.visualization as visualize
#import optuna.visualization.matplotlib as visualize
#refer to https://optuna.readthedocs.io/en/stable/tutorial/10_key_features/005_visualization.html#sphx-glr-tutorial-10-key-features-005-visualization-py 
#for how to plot stuff 


study = optuna.create_study()

#MUST be absolute path!
###100
#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test/optuna_db/ADNI_ALZ_ADCN-freeze-cls-UKByAa64a-train_100-batch_32.db"
#db_dir = "./finetune_test/optuna_db/ADNI_ALZ_ADCN-freeze-cls-None-train_100-batch_32.db"

#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test_same_seed/optuna_db/ADNI_ALZ_ADCN-freeze-cls-UKByAa64a-train_100-batch_32.db"

###20
#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test/optuna_db/ADNI_ALZ_ADCN-freeze-cls-UKByAa64a-train_20-batch_32.db"
#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test/optuna_db/ADNI_ALZ_ADCN-freeze-cls-None-train_20-batch_32.db"


#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test/optuna_db/test-tune_all-cls-y-Aware_Contrastive_MRI_epoch_99-train_20.db"
#db_dir = "/direct/sdcc+u/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_test/optuna_db/test-freeze-cls-None-train_20.db"


#db_dir = "./finetune_ABCD_fix_3_early_loss/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_64.db"
#db_dir = "./finetune_ABCD_fix_3_early_loss/optuna_db/ABCD_sex-tune_all-cls-UKBsim64a-train_80-batch_64.db"


#full epoch
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_ABCD_fix_3_full_epoch/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_ABCD_fix_3_full_epoch/optuna_db/ADNI_ALZ_ADCN-tune_all-cls-UKByAa64a-train_80-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_ABCD_fix_3_full_epoch/optuna_db/ADNI_ALZ_ADCN-tune_all-cls-None-train_80-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_ABCD_fix_3_full_epoch/optuna_db/ADNI_ALZ_ADCN-tune_all-cls-UKByAg64c-train_80-batch_64.db"


#full epoch with better pruning (not full pruning), batchsize 32
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_ABCD_fix_3_full_epoch/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"

#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_trash/optuna_db/test-tune_all-cls-y-Aware_Contrastive_MRI_epoch_99-train_50-batch_8.db"


###########
###iterative strat with ABCD
#80 (differing lr schedulers
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/test_lr_scheduler/custom_5/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/test_lr_scheduler/lr_plateau/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/test_lr_scheduler/null/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/test_lr_scheduler/onecyclelr/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"


#800
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/test_1000_samples/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_800-batch_32.db"


#
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_TEST_IF_EVAL_WORKS/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_trash/optuna_db/test-tune_all-cls-y-Aware_Contrastive_MRI_epoch_99-train_20-batch_8.db"


######TEST_2,3
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_2/only_iter_strat/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_2/550_cosine_annealing_decay/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_550-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_3/test_cosine_decay/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_3/test_cosine_decay_full_epoch/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_80-batch_32.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_3/ADHD_600_imb_strat/optuna_db/ABCD_ADHD-tune_all-cls-UKByAa64a-train_600-batch_64.db"

######TEST4
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/large_abcd_sex_64/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_7265-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/large_abcd_sex/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_7265-batch_128.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/large_abcd_sex_64_lr_plateau/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_7265-batch_64.db"

#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/large_abcd_sex_64_shorter/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_7265-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/large_abcd_sex_64_even_shorter/optuna_db/ABCD_sex-tune_all-cls-UKByAa64a-train_7265-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADHD_strict_upweight/optuna_db/ABCD_ADHD_strict-tune_all-cls-UKByAa64a-train_2213-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADHD_strict_balan_iter_strat_undone/optuna_db/ABCD_ADHD_strict-tune_all-cls-UKByAa64a-train_697-batch_64.db"


##ADHD
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADHD_strict_balan_iter_strat_undone_no_prune/optuna_db/ABCD_ADHD_strict-tune_all-cls-UKByAa64a-train_697-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADHD_strict_upweight_no_prune/optuna_db/ABCD_ADHD_strict-tune_all-cls-UKByAa64a-train_2213-batch_64.db"

##ADCN
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADCN_100_samples_100_epoch_balan/optuna_db/ADNI_ALZ_ADCN-tune_all-cls-UKByAa64a-train_80-batch_64.db"
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_4/ADCN_100_samples_100_epoch_balan_no_prune/optuna_db/ADNI_ALZ_ADCN-tune_all-cls-UKByAa64a-train_80-batch_64.db"

#####TEST5
##CHA ASDGDD
#db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_5/CHA_ASDGDD/optuna_db/CHA_ASDGDD-tune_all-cls-UKByAa64a-train_237-batch_32.db"
db_dir = "/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/finetune_RESULTS/TEST_5/CHA_ASDGDD/optuna_db/CHA_ASDGDD-tune_all-cls-None-train_237-batch_32.db"

url = "sqlite:///" + db_dir #os.path.abspath(os.path.join(os.getcwd(), db_dir)) #이건 왜 그런지 abs path로 안줘서 (그렇게 하려고 해도), 안되무!! 
storage = optuna.storages.RDBStorage(
    url = url,
    heartbeat_interval = 60, 
    grace_period = 120    
)
study = optuna.load_study(study_name = "test_study_name", 
                                storage = storage)

print(study.best_trial)

print(study.best_trial.value)

    
visualize.plot_optimization_history(study)#, )
#visualize.plot_intermediate_values(study)#,params = ["weight_decay", "learning_rate"])
#this doesn't work because I didn't use pruner, the intermediate values are not saved

#visualize.plot_pareto_front(study) #for 2~3 objectives
# Out:
# [I 2023-03-17 02:59:15,114] A new study created in memory with name: no-name-08912235-e9e0-4f25-be71-e96d20d89346
# ...

# %%
visualize.plot_edf(study)

# %%
visualize.plot_parallel_coordinate(study)

# %%
import matplotlib.pyplot as plt 
visualize.plot_contour(study)
#plt.xlim([1e-5,1e-4])
#plt.ylim([1e-3,1e2])

# %%
visualize.plot_slice(study)

# %%
visualize.plot_intermediate_values(study)

# %%
print("maybe reduce the parameter range and run again once the general landscape is found?")
optuna.visualization.plot_param_importances(study)
# Out:
# maybe reduce the parameter range and run again once the general landscape is found?

# %%
study.trials_dataframe().sort_values(by = "value", ascending = False)
# Out:
#      number     value             datetime_start          datetime_complete  \
# 21       21  0.815938 2023-03-14 20:51:30.790410 2023-03-15 02:03:21.200935
# 165     165  0.806856 2023-03-16 23:46:36.024348 2023-03-17 03:55:41.407336
# 33       33  0.806486 2023-03-15 02:26:08.868912 2023-03-15 09:48:14.725616
# 173     173  0.805853 2023-03-17 07:32:11.389165 2023-03-17 11:17:24.254250
# 28       28  0.804622 2023-03-15 01:54:50.565046 2023-03-15 09:34:12.750692
# ..      ...       ...                        ...                        ...
# 170     170       NaN 2023-03-17 03:55:41.510979 2023-03-17 05:10:14.560633
# 175     175       NaN 2023-03-17 09:49:17.253564                        NaT
# 176     176       NaN 2023-03-17 01:49:58.230143                        NaT
# 177     177       NaN 2023-03-17 11:17:24.382761                        NaT
# 178     178       NaN 2023-03-17 11:25:38.495701                        NaT
#
# ...

# %%
study.trials_dataframe()[130:]
# Out:
#      number     value             datetime_start          datetime_complete  \
# 130     130  0.750000 2023-03-16 02:56:16.661555 2023-03-16 03:09:29.206818
# 131     131  0.765528 2023-03-16 03:00:43.059283 2023-03-16 03:19:08.335367
# 132     132  0.753106 2023-03-16 03:09:30.088234 2023-03-16 03:32:20.448638
# 133     133       NaN 2023-03-16 03:19:08.881699 2023-03-16 13:39:12.277237
# 134     134       NaN 2023-03-16 03:32:21.470339 2023-03-16 13:39:32.730610
# 135     135       NaN 2023-03-16 04:36:08.084347 2023-03-16 23:46:35.745023
# 136     136       NaN 2023-03-16 04:36:12.163992 2023-03-16 23:46:35.761020
# 137     137       NaN 2023-03-16 04:36:22.083113 2023-03-16 23:46:40.887796
# 138     138       NaN 2023-03-16 13:37:04.413387 2023-03-16 14:59:25.053714
# 139     139       NaN 2023-03-16 13:37:09.408092 2023-03-16 13:39:12.192870
# 140     140       NaN 2023-03-16 13:37:19.567918 2023-03-16 13:39:32.669560
# ...

# %%
(study.trials_dataframe()['state'] == "COMPLETE").sum(), (study.trials_dataframe()['state'] == "FAIL").sum(),(study.trials_dataframe()['state'] == "PRUNED").sum(),(study.trials_dataframe()['state'] == "RUNNING").sum()

#UKB : 17, 24|
# Out:
# (44, 19, 110, 6)

# %%
#import pandas as pd 
#df = study.trials_dataframe()
#(study.trials_dataframe()['state'] == "RUNNING")

# %%
aa = [
{"epoch": 0, "training_loss": 56.12547969818115, "training_acc": 47.5, "val_loss": 13.903998136520386, "val_acc": 50.0, "val_auroc": 0.29, "time": 10.33},
{"epoch": 1, "training_loss": 55.680280685424805, "training_acc": 42.5, "val_loss": 13.943067789077759, "val_acc": 50.0, "val_auroc": 0.33, "time": 19.46},
{"epoch": 2, "training_loss": 55.314626693725586, "training_acc": 53.75, "val_loss": 14.008392095565796, "val_acc": 50.0, "val_auroc": 0.59, "time": 28.85},
{"epoch": 3, "training_loss": 55.10491180419922, "training_acc": 53.75, "val_loss": 13.964568376541138, "val_acc": 50.0, "val_auroc": 0.75, "time": 37.61},
{"epoch": 4, "training_loss": 55.24665927886963, "training_acc": 53.75, "val_loss": 13.879696130752563, "val_acc": 50.0, "val_auroc": 0.72, "time": 46.73},
{"epoch": 5, "training_loss": 55.10079574584961, "training_acc": 53.75, "val_loss": 13.852771520614624, "val_acc": 50.0, "val_auroc": 0.68, "time": 56.32},
{"epoch": 6, "training_loss": 55.46469593048096, "training_acc": 48.75, "val_loss": 13.857085704803467, "val_acc": 50.0, "val_auroc": 0.71, "time": 65.37},
{"epoch": 108, "training_loss": 3.8500548005104065, "training_acc": 98.75, "val_loss": 16.710094213485718, "val_acc": 70.0, "val_auroc": 0.97, "time": 1011.17},
{"epoch": 109, "training_loss": 3.7377825379371643, "training_acc": 98.75, "val_loss": 9.86747682094574, "val_acc": 75.0, "val_auroc": 0.98, "time": 1020.1},
{"epoch": 110, "training_loss": 5.826095938682556, "training_acc": 96.25, "val_loss": 8.939469456672668, "val_acc": 85.0, "val_auroc": 0.98, "time": 1029.52},
{"epoch": 111, "training_loss": 5.344181060791016, "training_acc": 98.75, "val_loss": 9.324005246162415, "val_acc": 80.0, "val_auroc": 0.98, "time": 1038.38},
{"epoch": 112, "training_loss": 9.184782028198242, "training_acc": 96.25, "val_loss": 63.21972846984863, "val_acc": 45.0, "val_auroc": 0.98, "time": 1047.49},
{"epoch": 113, "training_loss": 135.169779419899, "training_acc": 63.75, "val_loss": 46.70485019683838, "val_acc": 55.0, "val_auroc": 1.0, "time": 1057.34},
{"epoch": 114, "training_loss": 113.3829197883606, "training_acc": 57.5, "val_loss": 12.063819169998169, "val_acc": 75.0, "val_auroc": 1.0, "time": 1066.94},
{"epoch": 115, "training_loss": 24.08311653137207, "training_acc": 83.75, "val_loss": 7.0014166831970215, "val_acc": 80.0, "val_auroc": 1.0, "time": 1075.97},
{"epoch": 116, "training_loss": 14.19846248626709, "training_acc": 92.5, "val_loss": 23.178513050079346, "val_acc": 55.0, "val_auroc": 0.98, "time": 1085.11},
{"epoch": 117, "training_loss": 51.40529799461365, "training_acc": 60.0, "val_loss": 9.00514304637909, "val_acc": 85.0, "val_auroc": 0.98, "time": 1094.12},
{"epoch": 118, "training_loss": 16.965325355529785, "training_acc": 90.0, "val_loss": 13.197351694107056, "val_acc": 75.0, "val_auroc": 0.98, "time": 1103.09},
{"epoch": 119, "training_loss": 20.06559145450592, "training_acc": 90.0, "val_loss": 9.657222032546997, "val_acc": 70.0, "val_auroc": 0.98, "time": 1112.36},
{"epoch": 120, "training_loss": 12.167133092880249, "training_acc": 95.0, "val_loss": 7.987775802612305, "val_acc": 70.0, "val_auroc": 0.98, "time": 1121.43}]

# %%
import matplotlib.pyplot as plt
def plot_it(aa):
    epochs = [d['epoch'] for d in aa]
    val_aurocs = [d['val_auroc'] for d in aa]
    val_acc = [0.01*d['val_acc'] for d in aa]
    val_loss = [0.05*d['val_loss'] for d in aa]
    val_acc_auroc = [d['val_acc']*0.01*d['val_auroc'] for d  in aa]
    
    plt.plot(epochs, val_aurocs, label = 'valid auroc')
    plt.plot(epochs, val_acc, label = 'valid acc')
    #plt.plot(epochs, val_acc_auroc, label = 'valid acc_auroc')
    plt.plot(epochs, val_loss, label = 'valid loss (scale by 0.05)', linestyle = '--')
    plt.xlabel('Epoch')
    plt.axhline(y=0.5, color = 'b' , linestyle = ':' )
    plt.legend()
    plt.ylim(0,1)
    plt.show()

# %%
plot_it(aa)

# %%
plot_it(bb)
