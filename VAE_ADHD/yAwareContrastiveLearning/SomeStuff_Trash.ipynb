# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("/scratch/connectome/dyhan316/VAE_ADHD/junbeom_finetuning/csv/UKB_phenotype_gps_included.csv")

# %%
data.dropna(subset = "fluid")
# Out:
#         Unnamed: 0      eid  sex   age  income  SuicidalideationPassive  \
# 24              24  1000254  0.0  61.0     3.0                      NaN
# 40              40  1000414  1.0  63.0     3.0                      1.0
# 42              42  1000430  0.0  53.0     2.0                      0.0
# 66              66  1000672  0.0  66.0     2.0                      1.0
# 82              82  1000838  1.0  47.0     4.0                      0.0
# ...            ...      ...  ...   ...     ...                      ...
# 502326      502326  6023825  0.0  47.0    -1.0                      2.0
# 502367      502367  6024230  1.0  44.0     5.0                      NaN
# 502376      502376  6024326  0.0  58.0     3.0                      0.0
# 502411      502411  6024677  0.0  43.0    -1.0                      2.0
# 502445      502445  6025016  0.0  53.0     1.0                      0.0
#
#         SuicidalideationActive_Ever  SuicidalideationActive_PastYear  \
# ...

# %%
data[['fluid']] = (data[['fluid']]- data[['fluid']].mean())/data[['fluid']].std()

# %%
data[['age']] = (data[['age']]- data[['age']].mean())/data[['age']].std()

# %%
#data[['fluid']].hist()
#data[['age']].hist()
data[['fluid','age']].hist(bins = 16,sharex=True)
# Out:
# array([[<AxesSubplot: title={'center': 'fluid'}>,
#         <AxesSubplot: title={'center': 'age'}>]], dtype=object)

# %%
data['fluid'].std()
# Out:
# 2.0346957197725195
