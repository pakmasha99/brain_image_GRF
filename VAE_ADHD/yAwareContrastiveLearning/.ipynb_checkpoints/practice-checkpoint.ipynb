# %%
import pandas as pd
import os

meta_data = pd.read_csv('/global/cfs/cdirs/m3898/2.UKB/2.demo_qc/UKB_phenotype.csv' )
subjects = os.listdir('/global/cfs/cdirs/m3898/2.UKB/1.sMRI_fs_cropped')
    
# meta_data.loc[subj,] for subj in subjects

# %%
meta_data[meta_data['eid']==1000010]['age']
# Out:
# 0    67.0
# Name: age, dtype: float64

# %%
[(subj,meta_data[meta_data['eid']==int(subj[:7])]['sex'].values[0]) for subj in subjects]

# %%
tup = (4,4,4)
def my(x,y,z,u):
    return x+y[0]+z+u

my(3,tup,2,2)
# Out:
# 11

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

meta_data = pd.read_csv('/global/cfs/cdirs/m3898/2.UKB/2.demo_qc/UKB_phenotype.csv' )
subjects = os.listdir('/global/cfs/cdirs/m3898/2.UKB/1.sMRI_fs_cropped')

# %%
# %matplotlib inline
GPS = pd.read_csv('/global/cfs/cdirs/m3898/2.UKB/2.demo_qc/UKB_Intelligence_EUR_score_phiauto_SUM.txt',sep='\t' )
total = pd.merge(meta_data, GPS, left_on='eid', right_on = 'FID',how = 'left')

sns.heatmap(total.isnull(), cbar=False)

total.isna().sum()
# Out:
# eid                                     0
# sex                                     1
# age                                     1
# SuicidalideationPassive            345149
# SuicidalideationActive_Ever        345149
# SuicidalideationActive_PastYear    479302
# SelfHarmed_PastYear                495618
# SuicideAttempt_Ever                495618
# SuicideAttempt_PastYear            498925
# FID                                 15210
# IID                                 15210
# SCORE_auto                          15210
# dtype: int64

# %%
total
# Out:
#             eid  sex   age  SuicidalideationPassive  \
# 0       1000010  0.0  67.0                      NaN
# 1       1000028  0.0  46.0                      2.0
# 2       1000034  0.0  62.0                      NaN
# 3       1000045  0.0  42.0                      NaN
# 4       1000052  1.0  58.0                      2.0
# ...         ...  ...   ...                      ...
# 502481  6025376  1.0  46.0                      NaN
# 502482  6025387  0.0  63.0                      0.0
# 502483  6025391  1.0  68.0                      NaN
# 502484  6025400  0.0  67.0                      NaN
# 502485  6025417  NaN   NaN                      NaN
#
#         SuicidalideationActive_Ever  SuicidalideationActive_PastYear  \
# 0                               NaN                              NaN
# 1                               0.0                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               0.0                              NaN
# ...                             ...                              ...
# 502481                          NaN                              NaN
# 502482                          0.0                              NaN
# 502483                          NaN                              NaN
# 502484                          NaN                              NaN
# 502485                          NaN                              NaN
#
#         SelfHarmed_PastYear  SuicideAttempt_Ever  SuicideAttempt_PastYear  \
# 0                       NaN                  NaN                      NaN
# 1                       NaN                  NaN                      NaN
# 2                       NaN                  NaN                      NaN
# 3                       NaN                  NaN                      NaN
# 4                       NaN                  NaN                      NaN
# ...                     ...                  ...                      ...
# 502481                  NaN                  NaN                      NaN
# 502482                  NaN                  NaN                      NaN
# 502483                  NaN                  NaN                      NaN
# 502484                  NaN                  NaN                      NaN
# 502485                  NaN                  NaN                      NaN
#
#               FID        IID  SCORE_auto
# 0       1000010.0  1000010.0   -0.000002
# 1       1000028.0  1000028.0    0.000002
# 2       1000034.0  1000034.0   -0.000005
# 3       1000045.0  1000045.0   -0.000008
# 4       1000052.0  1000052.0    0.000002
# ...           ...        ...         ...
# 502481        NaN        NaN         NaN
# 502482  6025387.0  6025387.0   -0.000006
# 502483  6025391.0  6025391.0    0.000006
# 502484  6025400.0  6025400.0   -0.000003
# 502485        NaN        NaN         NaN
#
# [502486 rows x 12 columns]

# %%
total.to_csv('/global/cfs/cdirs/m3898/2.UKB/2.demo_qc/UKB_phenotype_gps_included.csv')

# %%
import pandas as pd
import os

meta_data= pd.read_csv('/global/cfs/cdirs/m3898/2.UKB/2.demo_qc/UKB_phenotype_gps_included.csv')
meta_data.dropna(subset=['SCORE_auto'])
# Out:
#         Unnamed: 0      eid  sex   age  SuicidalideationPassive  \
# 0                0  1000010  0.0  67.0                      NaN
# 1                1  1000028  0.0  46.0                      2.0
# 2                2  1000034  0.0  62.0                      NaN
# 3                3  1000045  0.0  42.0                      NaN
# 4                4  1000052  1.0  58.0                      2.0
# ...            ...      ...  ...   ...                      ...
# 502479      502479  6025352  0.0  53.0                      NaN
# 502480      502480  6025369  1.0  64.0                      NaN
# 502482      502482  6025387  0.0  63.0                      0.0
# 502483      502483  6025391  1.0  68.0                      NaN
# 502484      502484  6025400  0.0  67.0                      NaN
#
#         SuicidalideationActive_Ever  SuicidalideationActive_PastYear  \
# 0                               NaN                              NaN
# 1                               0.0                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               0.0                              NaN
# ...                             ...                              ...
# 502479                          NaN                              NaN
# 502480                          NaN                              NaN
# 502482                          0.0                              NaN
# 502483                          NaN                              NaN
# 502484                          NaN                              NaN
#
#         SelfHarmed_PastYear  SuicideAttempt_Ever  SuicideAttempt_PastYear  \
# 0                       NaN                  NaN                      NaN
# 1                       NaN                  NaN                      NaN
# 2                       NaN                  NaN                      NaN
# 3                       NaN                  NaN                      NaN
# 4                       NaN                  NaN                      NaN
# ...                     ...                  ...                      ...
# 502479                  NaN                  NaN                      NaN
# 502480                  NaN                  NaN                      NaN
# 502482                  NaN                  NaN                      NaN
# 502483                  NaN                  NaN                      NaN
# 502484                  NaN                  NaN                      NaN
#
#               FID        IID    SCORE_auto
# 0       1000010.0  1000010.0 -2.327840e-06
# 1       1000028.0  1000028.0  1.981540e-06
# 2       1000034.0  1000034.0 -4.524330e-06
# 3       1000045.0  1000045.0 -8.199390e-06
# 4       1000052.0  1000052.0  1.635410e-06
# ...           ...        ...           ...
# 502479  6025352.0  6025352.0 -5.676810e-06
# 502480  6025369.0  6025369.0 -1.381710e-07
# 502482  6025387.0  6025387.0 -5.844950e-06
# 502483  6025391.0  6025391.0  5.786590e-06
# 502484  6025400.0  6025400.0 -3.305320e-06
#
# [487276 rows x 13 columns]

# %%
total['SCORE_auto'].hist()
total['SCORE_auto'].std()
# Out:
# 2.970351490178418e-06

# %%
total['age'].hist()
total['age'].std()
# Out:
# 8.092326434622889

# %%
from sklearn.metrics.pairwise import rbf_kernel
import numpy as np
labels = total['SCORE_auto'].to_list() * 2
all_labels = np.array(total['SCORE_auto'].to_list() * 2).reshape(-1,1)
weights = rbf_kernel(all_labels, all_labels, gamma=1./(2*5**2)) # [2N, 2N]
#weights = weights * (1 - np.eye(2*N)) # puts 0 on the diagonal
