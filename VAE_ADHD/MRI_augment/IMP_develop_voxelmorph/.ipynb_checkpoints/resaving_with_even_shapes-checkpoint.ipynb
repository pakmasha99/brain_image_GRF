# %%
import pandas as pd
import os
import numpy as np 
import matplotlib.pyplot as plt 
sub_dir = "/scratch/connectome/dyhan316/sample_files_for_brain_storm/list_for_original.txt"
pd.read_csv(sub_dir)


for npy in pd.read_csv(sub_dir).values:
    print(np.load(npy[0]).shape)
# Out:
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# (99, 117, 95)
# ...

# %%
sample = npy[0]

haha = sample.split('/')
print(haha)
haha[-2] = "multiple_of_16_ABCD_trash"
haha
#"/".join(haha)
# Out:
# ['', 'scratch', 'connectome', 'dyhan316', 'sample_files_for_brain_storm', 'trash_ABCD_sample_data', 'NDARINV1ZD6AF6H.npy']
# ['',
#  'scratch',
#  'connectome',
#  'dyhan316',
#  'sample_files_for_brain_storm',
#  'multiple_of_16_ABCD_trash',
#  'NDARINV1ZD6AF6H.npy']

# %%
os.mkdir("/scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash")
for filename in pd.read_csv(sub_dir).values:
    img = np.load(filename[0])
    new_name = filename[0].split('/')
    new_name[-2] = "multiple_of_16_ABCD_trash"
    
    new_name = "/".join(new_name)
    print(new_name)
    #print(filename)
    new_img = img[:96,:112,]
    new_img = np.pad(new_img, pad_width =  ((0,0),(0,0),(0,1)))
    
    np.save(new_name,new_img)
# Out:
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV10EP1VM2.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV10HWA6YU.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV10KXDDBK.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV11THDW9B.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV1285PMCK.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV1378XGLA.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV138RG20T.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV13PRF0TM.npy
# /scratch/connectome/dyhan316/sample_files_for_brain_storm/multiple_of_16_ABCD_trash/NDARINV14992W6G.npy
# ...

# %%
"/".join(haha)
# Out:
# '/scratch/connectome/dyhan316/sample_files_for_brain_storm/even_shape_ABCD_shape/NDARINV1ZD6AF6H.npy'

# %%
img = np.load(sample)
new_img = img[:96,:112,]

new_img = np.pad(new_img, pad_width =  ((0,0),(0,0),(0,1)))
plt.imshow(new_img[:,:,50])
new_img.shape
# Out:
# (96, 112, 96)

# %%
new_new_img = np.pad(new_img, pad_width =  ((0,0),(0,0),(0,1)))
new_new_img.shape
# Out:
# (96, 112, 96)

# %%
plt.imshow(new_new_img[40,:,:])

# %%
plt.imshow(image[40])

# %%
plt.imshow(image[40,:,:90])

# %%
plt.imshow(image[40,10:,:])

# %%
plt.imshow(image[:,:,45])
#plt.imshow(image[:,:,])

# %%
plt.imshow(image[40:,:,45])

# %%
99, 117, 95
